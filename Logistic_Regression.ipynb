# %% [markdown]
# <a href="https://colab.research.google.com/github/Ayush-2026/ML-Lab/blob/main/Logistic_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.datasets import make_classification
from matplotlib import pyplot as plt
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
import pandas as pd
import numpy as np

# %%
x,y = make_classification(
    n_samples = 100,
    n_features = 1,
    n_classes = 2,
    n_clusters_per_class = 1,
    flip_y = 0.03,
    n_informative = 1,
    n_redundant = 0,
    n_repeated = 0
    )

# %%
plt.scatter(x, y, c=y, cmap = 'rainbow')
plt.title('Scatter Plot of Logistic Regression')
plt.xlabel('X')
plt.ylabel('Y')
plt.show()

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, random_state = 1)

# %%
len(x_train)
# Out:
# 75

# %%
len(y_train)
# Out:
# 75

# %%
len(x_test)
# Out:
# 25

# %%
len(y_test)
# Out:
# 25

# %%
log_reg = LogisticRegression()
log_reg.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
                   intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
                   penalty='12', random_state=None, solver='liblinear', tol=0.0001,
                   verbose=0, warm_start=False)
# Out:
# LogisticRegression(multi_class='ovr', n_jobs=1, penalty='12',
#                    solver='liblinear')

# %%
print(log_reg.coef_)
print(log_reg.intercept_)
# Out:
# [[3.65920013]]
# [-0.92253158]

# %%
y_pred = log_reg.predict(x_test)

# %%
confusion_matrix(y_test, y_pred)
# Out:
# array([[14,  0],
#        [ 0, 11]])

# %%
df = pd.read_csv('framingham.csv')
df
# Out:
#       male  age  education  currentSmoker  cigsPerDay  BPMeds  \
# 0        1   39        4.0              0         0.0     0.0
# 1        0   46        2.0              0         0.0     0.0
# 2        1   48        1.0              1        20.0     0.0
# 3        0   61        3.0              1        30.0     0.0
# 4        0   46        3.0              1        23.0     0.0
# ...    ...  ...        ...            ...         ...     ...
# 4233     1   50        1.0              1         1.0     0.0
# 4234     1   51        3.0              1        43.0     0.0
# 4235     0   48        2.0              1        20.0     NaN
# 4236     0   44        1.0              1        15.0     0.0
# 4237     0   52        2.0              0         0.0     0.0
#
#       prevalentStroke  prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  \
# 0                   0             0         0    195.0  106.0   70.0  26.97
# ...

# %%
print(df.head())
print(df.describe())
print(df.info())
# Out:
#    male  age  education  currentSmoker  cigsPerDay  BPMeds  prevalentStroke  \
# 0     1   39        4.0              0         0.0     0.0                0
# 1     0   46        2.0              0         0.0     0.0                0
# 2     1   48        1.0              1        20.0     0.0                0
# 3     0   61        3.0              1        30.0     0.0                0
# 4     0   46        3.0              1        23.0     0.0                0
#
#    prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  glucose  \
# 0             0         0    195.0  106.0   70.0  26.97       80.0     77.0
# 1             0         0    250.0  121.0   81.0  28.73       95.0     76.0
# 2             0         0    245.0  127.5   80.0  25.34       75.0     70.0
# 3             1         0    225.0  150.0   95.0  28.58       65.0    103.0
# 4             0         0    285.0  130.0   84.0  23.10       85.0     85.0
#
#    TenYearCHD
# 0           0
# 1           0
# ...

# %%
print(df.isnull().sum())
# Out:
# male                 0
# age                  0
# education          105
# currentSmoker        0
# cigsPerDay          29
# BPMeds              53
# prevalentStroke      0
# prevalentHyp         0
# diabetes             0
# totChol             50
# sysBP                0
# diaBP                0
# BMI                 19
# heartRate            1
# glucose            388
# TenYearCHD           0
# dtype: int64

# %%
print(df.columns)
# Out:
# Index(['male', 'age', 'education', 'currentSmoker', 'cigsPerDay', 'BPMeds',
#        'prevalentStroke', 'prevalentHyp', 'diabetes', 'totChol', 'sysBP',
#        'diaBP', 'BMI', 'heartRate', 'glucose', 'TenYearCHD'],
#       dtype='object')

# %%
df.fillna(value={'male':'default_value'},inplace = True)
df.fillna(method='ffill',inplace = True)
df.fillna(method='bfill',inplace = True)
# Out:
# <ipython-input-98-7a349abaca83>:2: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method='ffill',inplace = True)
# <ipython-input-98-7a349abaca83>:3: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method='bfill',inplace = True)

# %%
df.rename(columns={'old_name': 'new_name'},inplace=True)

# %%
df['male'] = df['male'].astype('int')  # Convert to integer

# %%
df.drop_duplicates(inplace=True)

# %%
threshold = 0.5

# %%
df = df[df['male'] > threshold]

# %%
df.to_csv('cleaned_framingham.csv', index=False)

# %%
df2 = pd.read_csv('cleaned_framingham.csv')
df2
# Out:
#       male  age  education  currentSmoker  cigsPerDay  BPMeds  \
# 0        1   39        4.0              0         0.0     0.0
# 1        1   48        1.0              1        20.0     0.0
# 2        1   52        1.0              0         0.0     0.0
# 3        1   43        1.0              1        30.0     0.0
# 4        1   46        1.0              1        15.0     0.0
# ...    ...  ...        ...            ...         ...     ...
# 1814     1   43        4.0              1        20.0     0.0
# 1815     1   58        3.0              0         0.0     0.0
# 1816     1   68        1.0              0         0.0     0.0
# 1817     1   50        1.0              1         1.0     0.0
# 1818     1   51        3.0              1        43.0     0.0
#
#       prevalentStroke  prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  \
# 0                   0             0         0    195.0  106.0   70.0  26.97
# ...

# %%
df3 = pd.read_csv('cleaned_framingham.csv')
df3
# Out:
#       male  age  education  currentSmoker  cigsPerDay  BPMeds  \
# 0        1   39        4.0              0         0.0     0.0
# 1        1   48        1.0              1        20.0     0.0
# 2        1   52        1.0              0         0.0     0.0
# 3        1   43        1.0              1        30.0     0.0
# 4        1   46        1.0              1        15.0     0.0
# ...    ...  ...        ...            ...         ...     ...
# 1814     1   43        4.0              1        20.0     0.0
# 1815     1   58        3.0              0         0.0     0.0
# 1816     1   68        1.0              0         0.0     0.0
# 1817     1   50        1.0              1         1.0     0.0
# 1818     1   51        3.0              1        43.0     0.0
#
#       prevalentStroke  prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  \
# 0                   0             0         0    195.0  106.0   70.0  26.97
# ...

# %%
x,y = make_classification(
    n_samples = 100,
    n_features = 1,
    n_classes = 2,
    n_clusters_per_class = 1,
    flip_y = 0.03,
    n_informative = 1,
    n_redundant = 0,
    n_repeated = 0
    )

# %%
plt.scatter(x, y, c=y, cmap = 'rainbow')
plt.title('Scatter Plot of Logistic Regression')
plt.xlabel('X')
plt.ylabel('Y')
plt.show()
